# %%
from ludwig.api import LudwigModel
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.

# %%
ludwig_model = LudwigModel.load('/Users/benmackenzie/projects/titanic/results/experiment_run_0/model')
# Out:
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
import pandas as pd
df = pd.read_csv('~/data/titanic/train.csv')

# %%
ludwig_model.predict(df)
# Out:
# WARNING:tensorflow:From /Users/benmackenzie/projects/ludwig/venv/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /Users/benmackenzie/projects/titanic/results/experiment_run_0/model/model_weights
#      Survived_predictions  Survived_probabilities
# 0                   False                0.078358
# 1                    True                0.998610
# 2                   False                0.104154
# 3                    True                0.963715
# 4                   False                0.010992
# 5                   False                0.089084
# 6                   False                0.272965
# 7                    True                0.965399
# ...

# %%
import yaml

with open("model_definition.yaml", 'r') as stream:
    model_def = yaml.safe_load(stream)
model_def
# Out:
# {'input_features': [{'name': 'Pclass', 'type': 'category'},
#   {'name': 'Sex', 'type': 'category'},
#   {'name': 'Age',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean'}},
#   {'name': 'SibSp', 'type': 'numerical'},
#   {'name': 'Parch', 'type': 'numerical'},
#   {'name': 'Fare',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean'}},
#   {'name': 'Embarked', 'type': 'category'}],
#  'output_features': [{'name': 'Survived', 'type': 'binary'}]}

# %%
ludwig_model = LudwigModel(model_def)
train_status = ludwig_model.train(data_csv='/Users/benmackenzie/data/titanic/train.csv')
# Out:
# /Users/benmackenzie/projects/ludwig/venv/lib/python3.7/site-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)

# %%
ludwig_model.predict(df)
# Out:
#      Survived_predictions  Survived_probabilities
# 0                   False                0.077996
# 1                    True                0.998580
# 2                   False                0.102651
# 3                    True                0.964863
# 4                   False                0.011091
# 5                   False                0.098098
# 6                   False                0.287511
# 7                    True                0.964234
# 8                   False                0.174193
# 9                    True                0.984069
# 10                   True                0.953282
# 11                  False                0.007583
# 12                  False                0.111489
# 13                  False                0.352477
# 14                  False                0.438310
# 15                  False                0.003762
# 16                   True                0.997640
# 17                  False                0.052151
# ...

# %%
# !pwd
# Out:
# /Users/benmackenzie/projects/titanic

# %%
# !mkdir model

# %%
ludwig_model.save('model')

# %%
# !ls model
# Out:
# checkpoint                        model_weights.index
# model_hyperparameters.json        model_weights.meta
# model_weights.data-00000-of-00001 train_set_metadata.json

# %%
import tarfile

with tarfile.open('titanic_model.tar.gz', 'w:gz') as tar:
    tar.add('model')

# %%
# !ls -l
# Out:
# total 120
# drwxr-xr-x  8 benmackenzie  staff    256 16 Jul 08:39 model
# -rw-r--r--  1 benmackenzie  staff    574 16 Jul 07:35 model_definition.yaml
# drwxr-xr-x  5 benmackenzie  staff    160 16 Jul 08:34 results
# -rw-r--r--  1 benmackenzie  staff  32729 16 Jul 08:39 titanic.ipynb
# -rw-r--r--  1 benmackenzie  staff  24487 16 Jul 08:39 titanic_model.tar.gz

# %%
with tarfile.open('titanic_model.tar.gz', 'r:gz') as tar:
    tar.extractall('/tmp/titanic')

# %%
ludwig_model2 = LudwigModel.load('/tmp/titanic/model')

# %%
ludwig_model2.predict(df)
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/titanic/model/model_weights
#      Survived_predictions  Survived_probabilities
# 0                   False                0.077996
# 1                    True                0.998580
# 2                   False                0.102651
# 3                    True                0.964863
# 4                   False                0.011091
# 5                   False                0.098098
# 6                   False                0.287511
# 7                    True                0.964234
# 8                   False                0.174193
# 9                    True                0.984069
# 10                   True                0.953282
# 11                  False                0.007583
# 12                  False                0.111489
# 13                  False                0.352477
# 14                  False                0.438310
# 15                  False                0.003762
# ...
